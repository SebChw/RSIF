# %% [markdown]
# This notebook loads all used datasets and creates table with simple statistics about them.

# %%
import sys
sys.path.append("../data")
from pathlib import Path
import pandas as pd
from datasets_const import NUMERICAL_DATA_NAMES, CATEGORICAL_DATA_NAMES, GRAPH_DATA_NAMES, CV_DATA_NAMES, NLP_DATA_NAMES, TIMESERIES_DATA_NAMES, MULTIOMICS_DATA_NAMES, SET_DATA_NAMES
from data_getter import get_npz_dataset, get_categorical_dataset, get_glocalkd_dataset, get_timeseries, get_multiomics_data, get_sets_data

# %load_ext autoreload

# %autoreload 2

# %%
datasets_description = []

# %%
def append_desc(path, f, type_, kwargs={}):
    data = f(path, **kwargs)
    X, y, name = data["X"], data["y"], data["name"]

    datasets_description.append({
        "name": name,
        "n_instances": X.shape[0],
        "n_features": X.shape[1],
        "outlier_ratio": f"{(y == 1).sum() * 100 / len(y):.2f}%",
        "type": type_
    })

# %% [markdown]
# ### Numerical

# %%
NUMERICAL_ROOT = Path("../data/numerical")

for path in NUMERICAL_DATA_NAMES:
    path = NUMERICAL_ROOT / path
    append_desc(path, get_npz_dataset, "numerical")

# %% [markdown]
# CATEGORICAL

# %%
CATEGORICAL_ROOT = Path("../data/categorical")

for path in CATEGORICAL_DATA_NAMES:
    path = CATEGORICAL_ROOT / path
    append_desc(path, get_categorical_dataset, "categorical")

# %% [markdown]
# ### GRAPH

# %%
GRAPH_PATH = "../data/graph/"
for name in GRAPH_DATA_NAMES:
    data = get_glocalkd_dataset(GRAPH_PATH, name)
    X, y, name = data["X"], data["y"], data["name"]

    datasets_description.append({
        "name": name,
        "n_instances": X.shape[0],
        "n_features": 1,
        "outlier_ratio": f"{(y == 1).sum() * 100 / len(y):.2f}%",
        "type": "graph"
    })

# %% [markdown]
# ### TIME SERIES

# %%
TIMESERIES_PATH = "../data/timeseries"
for name in TIMESERIES_DATA_NAMES:
    data = get_timeseries(TIMESERIES_PATH, name)
    X, y, name = data["X"], data["y"], data["name"]

    datasets_description.append({
        "name": name,
        "n_instances": X.shape[0],
        "n_features": X.shape[1],
        "outlier_ratio": f"{(y == 1).sum() * 100 / len(y):.2f}%",
        "type": "timeseries"
    })

# %% [markdown]
# NLP and CV

# %%
NUMERICAL_ROOT = Path("../data/adBench/CV_by_ResNet18")

for path in CV_DATA_NAMES:
    path = NUMERICAL_ROOT / path
    append_desc(path, get_npz_dataset, "CV embedding")

# %%
NUMERICAL_ROOT = Path("../data/adBench/NLP_by_RoBERTa")

for path in NLP_DATA_NAMES:
    path = NUMERICAL_ROOT / path
    
    append_desc(path, get_npz_dataset, "NLP embedding")

# %% [markdown]
# #### Multiomics

# %%
MULTIOMICS_ROOT = Path("../data/mixed")

for path in MULTIOMICS_DATA_NAMES:
    append_desc(MULTIOMICS_ROOT, get_multiomics_data, "multiomics", {"data_name": path, "for_risf": False})

# %% [markdown]
# ### Sequences of sets

# %%
SET_ROOT = Path("../data/mixed")

for path in SET_DATA_NAMES:
    append_desc(SET_ROOT, get_sets_data, "set", {"data_name": path, "for_risf": False})

# %% [markdown]
# ### description

# %%
pd.DataFrame(datasets_description)
# Out:
#                                   name  n_instances  n_features outlier_ratio  \
# 0                             14_glass          214           7         4.21%
# 1                            20_letter         1600          32         6.25%
# 2                      21_Lymphography          148          18         4.05%
# 3                              25_musk         3062         166         3.17%
# 4                         26_optdigits         5216          64         2.88%
# 5                         2_annthyroid         7200           6         7.42%
# 6                        31_satimage-2         5803          36         1.22%
# 7                            36_speech         3686         400         1.65%
# 8                           38_thyroid         3772           6         2.47%
# 9                            40_vowels         1456          12         3.43%
# 10                         41_Waveform         3443          21         2.90%
# 11                              42_WBC          223           9         4.48%
# 12                             43_WDBC          367          30         2.72%
# 13                             44_Wilt         4819           5         5.33%
# 14                            6_cardio         1831          21         9.61%
# 15                          ad_nominal         3263        1555        13.91%
# 16  AID362red_train_allpossiblenominal         4278         117         1.40%
# 17           apascal_entire_trainvsall        12694          64         1.39%
# 18                         cmc-nominal         1472          22         1.97%
# 19                    Reuters-corn-100        12896         100         1.84%
# 20          solar-flare_FvsAll-cleaned         1065          37         4.04%
# 21                                AIDS         1680           1         4.76%
# 22                                 BZR          335           1         4.78%
# 23                                COX2          383           1         4.70%
# 24                                  DD          726           1         4.82%
# 25                                DHFR          484           1         4.75%
# 26                             ENZYMES          105           1         4.76%
# 27                                NCI1         2160           1         4.77%
# 28                       PROTEINS_full          696           1         4.74%
# 29                         Earthquakes          387         512         4.91%
# 30                         ECGFiveDays          465         136         4.95%
# 31         MiddlePhalanxOutlineCorrect          583          80         4.97%
# 32               SonyAIBORobotSurface1          367          70         4.90%
# 33                          TwoLeadECG          611          82         4.91%
# 34                           CIFAR10_0         5263         512         5.00%
# 35                      FashionMNIST_0         6315         512         4.99%
# 36                              SVHN_0         5208         512         4.99%
# 37                            agnews_0        10000         768         5.00%
# 38                              amazon        10000         768         5.00%
# 39                                imdb        10000         768         5.00%
# 40                                yelp        10000         768         5.00%
# 41                              breast          770          50         3.64%
# 42                             ovarian          125          50         4.80%
# 43                              rosmap          177         600         4.52%
# 44                               items          210         485         4.76%
# 45                              length          210         463         4.76%
# 46                               order          210         464         4.76%
#
#              type
# 0       numerical
# 1       numerical
# 2       numerical
# 3       numerical
# 4       numerical
# 5       numerical
# 6       numerical
# 7       numerical
# 8       numerical
# 9       numerical
# 10      numerical
# 11      numerical
# 12      numerical
# 13      numerical
# 14      numerical
# 15    categorical
# 16    categorical
# 17    categorical
# 18    categorical
# 19    categorical
# 20    categorical
# 21          graph
# 22          graph
# 23          graph
# 24          graph
# 25          graph
# 26          graph
# 27          graph
# 28          graph
# 29     timeseries
# 30     timeseries
# 31     timeseries
# 32     timeseries
# 33     timeseries
# 34   CV embedding
# 35   CV embedding
# 36   CV embedding
# 37  NLP embedding
# 38  NLP embedding
# 39  NLP embedding
# 40  NLP embedding
# 41     multiomics
# 42     multiomics
# 43     multiomics
# 44            set
# 45            set
# 46            set
